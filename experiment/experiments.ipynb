# %%
import pandas as pd

# %%
data = pd.read_csv("../playground-series-s3e8/train.csv")
data.head(10)
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# 5   5   1.51  Very Good     J     SI1   62.8   58.0  7.34  7.29  4.59   7506
# 6   6   0.74      Ideal     E     VS2   61.8   57.0  5.76  5.79  3.57   3229
# 7   7   1.34    Premium     G     SI2   62.5   57.0  7.00  7.05  4.38   6224
# 8   8   0.30      Ideal     F      IF   62.0   56.0  4.35  4.37  2.70    886
# 9   9   0.30       Good     J     VS1   63.6   57.0  4.26  4.28  2.72    421

# %%
data["color"].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %% [markdown]
# data.sample(10)

# %%
data.sample(10)
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 182606  182606   1.02      Ideal     G     SI1   62.2   56.0  6.46  6.43
# 67906    67906   0.72      Ideal     E     SI1   61.3   56.0  5.77  5.79
# 102217  102217   0.57      Ideal     E     VS1   61.4   56.0  5.33  5.35
# 183521  183521   1.07      Ideal     F     VS2   62.4   56.0  6.55  6.53
# 102458  102458   0.70      Ideal     E     VS2   61.5   57.0  5.73  5.69
# 20633    20633   0.31  Very Good     I      IF   63.5   58.0  4.31  4.26
# 105349  105349   0.90    Premium     D     SI1   63.6   61.0  6.13  6.08
# 113283  113283   0.41       Good     D     SI1   63.1   58.0  4.69  4.73
# 22111    22111   0.54      Ideal     I     SI1   62.5   57.0  5.22  5.20
# 188894  188894   1.06      Ideal     E     SI1   62.0   57.0  6.51  6.55
#
#            z  price
# 182606  4.00   5204
# 67906   3.54   3130
# 102217  3.28   1965
# 183521  4.08   7125
# 102458  3.51   3275
# 20633   2.72    828
# ...

# %%
data.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
data.shape
# Out:
# (193573, 11)

# %%
data
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 0            0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33
# 1            1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12
# 2            2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73
# 3            3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41
# 4            4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61
# ...        ...    ...        ...   ...     ...    ...    ...   ...   ...
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 0       4.55  13619
# 1       5.05  13387
# 2       3.50   2772
# ...

# %%
data.drop(labels=["id"], axis=1,inplace=True)

# %%
print (data.head(5))
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
cat_columns = data.columns[data.dtypes=="int64"]
data[cat_columns].describe().T
# Out:
#           count         mean          std    min    25%     50%     75%  \
# price  193573.0  3969.155414  4034.374138  326.0  951.0  2401.0  5408.0
#
#            max
# price  18818.0

# %%
for col in cat_columns:
    print(data[col].value_counts())
    print (f"{len(data[col].value_counts())}")
    print ("-------------------------------")
# Out:
# price
# 544      542
# 605      464
# 789      454
# 828      438
# 776      437
#         ...
# 3807       1
# 4621       1
# 11165      1
# 9609       1
# 12094      1
# Name: count, Length: 8738, dtype: int64
# 8738
# -------------------------------

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))

num_columns = data.columns[data.dtypes != object]
print (num_columns)
for col in cat_columns:
    sns.histplot(data=data, x=col, kde=True)
    print("\n")
    plt.show()
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')

# %%
sns.heatmap(data[num_columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
cut_map={"Fair":1, "Good":2, "Very Good": 3, "Premium":4, "Ideal": 5}
clarity_map={"I1":1, "SI1":2, "IS2":3, "VS1":4, "VS2":5, "VVS1":6, "VVS2":7, "IF":8}
color_map = {"D":1, "E":2, "F":3, "G":4, "H":5, "I":6, "J":7}

# %% [markdown]
# SI1	62.5	55.0	4.61	4.62	2.88	818
# 186887	186887	1.14	Ideal	F	VS2	60.0	57.0	6.78	6.83	4.08	8074
# 65661	65661	2.54	Ideal	I	SI1	62.9	56.0	8.68	8.65	5.46	17784
# 3829	3829	1.00	Very Good	J	SI2	63.3	59.0	6.34	6.25	3.99	3461
# 161807	161807	0.53	Ideal	E	VS2	61.4	56.0	5.22	5.19	3.20	1711
# 73495	73495	0.30	Good	G	VVS2	63.8	57.0	4.22	4.26	2.70	684
# 109581	109581	1.00	Ideal	G	SI1	61.9	54.0	6.43	6.48	3.99	4862
# 114693	114693	0.41	Very Good	G	VVS1	60.7	57.0	4.82	4.85	2.93	1096
# 104237	104237	0.51	Ideal	H	VS1	61.7	57.0	5.11	5.14	3.16	1436
# 182942	182942	0.81	Ideal	G	VS2

# %%
data
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]

# %%
data["cut"]=data["cut"].map(cut_map)
data["clarity"]=data["clarity"].map(clarity_map)
data["color"]=data["color"].map(color_map)

# %%
data
# Out:
#         carat  cut  color  clarity  depth  table     x     y     z  price
# 0        1.52    4      3      5.0   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03    3      7      NaN   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70    5      4      4.0   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32    5      4      4.0   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    4      4      5.0   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 193568   0.31    5      1      7.0   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    4      4      7.0   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73    3      3      2.0   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34    3      1      2.0   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71    2      2      NaN   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]
